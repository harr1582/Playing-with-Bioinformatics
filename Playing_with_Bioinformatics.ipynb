# %%
list_ = open ("dataset_2_7 (3).txt").read().split()
text = list_[0]
pattern = list_[1]
print(text)
pattern
# Out:
# ...
# 'ATGTATTAT'

# %%
#How many times does the pattern appear in the text including overlaps?
sum(text[i:i+len(pattern)] == pattern for i in range(len(text)))
# Out:
# 36

# %%
    #Come back to this
    
    #FrequentWords(Text, k)
    #     FrequentPatterns ← an empty set
    #     for i ← 0 to |Text| − k
    #         Pattern ← the k-mer Text(i, k)
    #         Count(i) ← PatternCount(Text, Pattern)
    #     maxCount ← maximum value in array Count
    #     for i ← 0 to |Text| − k
    #         if Count(i) = maxCount
    #             add Text(i, k) to FrequentPatterns
    #     remove duplicates from FrequentPatterns
    #     return FrequentPatterns

def FrequentWords(Text, k):
  range_A = range(0,Text-k)
  FrequentPatterns = []
  count = 0

  for i in range_A:
    Pattern = Text(i,k)
    pattern_num = Text.count(Pattern)
  for i in range_A:
    if Count(i) = maxCount
  k= Text[-1]
  for i in range_A:
      Pattern = Text(i,k)
      Count(i)
# Out:
#   File "<ipython-input-7-ad214eecc0dd>", line 2
#     FrequentPatterns ← an empty set
#     ^
# IndentationError: unexpected indent

# %%
# 1.3 Building a reverse complement for a gene
text = open ("dataset_3_2 (4).txt").read()

comp_nucs = []
for each in range(0, len(text)): 
  i = 0
  
  
  if text[each] == 'A':
    comp_nucs.append('T')
  if text[each] == 'T':
    comp_nucs.append('A')
  if text[each] == 'C':
    comp_nucs.append('G')
  if text[each] == 'G':
    comp_nucs.append('C')

merged = ''.join(comp_nucs)
merged
def reverse(string_): 
    string_ = string_[::-1] 
    return string_
reverse(merged)
# Out:
# '...'

# %%
#What index does the pattern appear at in the text?

list_ = open ("dataset_2_7 (3).txt").read().split()
text = list_[0]
pattern = list_[1]
print(pattern)
print(text)


for i in range(len(text)):
  pattern == text[i:i+len(pattern)]
# Out:
# ATGTATTAT
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-0977e00d5bae> in <module>()
#       8 indexes = []
#       9 for i in range(len(text)):
# ---> 10   indexes.append(text.loc[i:i+len(pattern)])
#      11
#
# AttributeError: 'str' object has no attribute 'loc'
